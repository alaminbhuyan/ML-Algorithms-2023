# %% [markdown]
# ### Date: 19/01/2023

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import sklearn
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
print("numpy version: ", np.__version__)
print("pandas version: ", pd.__version__)
print("sklearn version: ", sklearn.__version__)
print("matplotlib version: ", matplotlib.__version__)

# numpy version:  1.24.1
# pandas version:  1.5.2
# sklearn version:  1.2.0
# matplotlib version:  3.6.3
# Out:
# numpy version:  1.24.1
# pandas version:  1.5.2
# sklearn version:  1.2.0
# matplotlib version:  3.6.3

# %%
X, y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=70, random_state=16)

# %%
X
# Out:
# array([[-1.52847346],
#        [ 0.12794872],
#        [ 0.06633037],
#        [-0.59446798]])

# %%
y
# Out:
# array([-128.31627254,   54.4890707 ,   49.4266706 ,  -14.65253558])

# %%
# Let's plot it

plt.scatter(x=X, y=y)
plt.show()

# %% [markdown]
# ### At first using Linear Regression

# %%
# Create Linear regression model

lr = LinearRegression()

# %%
lr.fit(X=X, y=y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([110.22927295])

# %%
lr.intercept_
# Out:
# 43.38549528052026

# %%
# plot the line for linear regression

plt.scatter(x=X, y=y)
plt.plot(X, lr.predict(X=X), color="red")
plt.show()

# %% [markdown]
# ## Let's apply gradient descent
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Lets apply Gradient Descent assuming slope is constant m = 110.22927295
# And let's assume the starting value for intercept b = -10

# since we have m and b value so we can predict using y = mx + b

m = 110.22927295
b = -10

y_pred = ((m * X) + b)

y_pred
# Out:
# array([[-178.48251809],
#        [   4.10369451],
#        [  -2.68845113],
#        [ -75.52777323]])

# %%
# make 1-D

y_pred = y_pred.reshape(4)
y_pred
# Out:
# array([-178.48251809,    4.10369451,   -2.68845113,  -75.52777323])

# %%
# first plot when b = -10

plt.scatter(x=X, y=y)
plt.plot(X, lr.predict(X=X), color="red", label="OLS")
plt.plot(X, y_pred, color="green", label="b=-10")
plt.legend()
plt.show()

# %% [markdown]
# ### iteration-1

# %%
# Lets take learning rate = 0.1
learning_rate = 0.1

# calculate the slope value
slope = -2 * np.mean(y - (m*X.ravel()) - b)
# updating the intercept value or b
b = b - (learning_rate * slope)
# predict the output
y_pred1 = ((m*X) + b).reshape(4)
print(y_pred1)

plt.scatter(x=X, y=y)
plt.plot(X, lr.predict(X=X), color="red", label="OLS")
plt.plot(X, y_pred, color="green", label="b=-10")
plt.plot(X, y_pred1, color="blue", label="b={}".format(round(b,4)))
plt.legend()
plt.show()
# Out:
# [-167.80541903   14.78079356    7.98864793  -64.85067417]

# %% [markdown]
# ### iteration-2

# %%
# Lets take learning rate = 0.1
learning_rate = 0.1

# calculate the slope value
slope = -2 * np.mean(y - (m*X.ravel()) - b)
# updating the intercept value or b
b = b - (learning_rate * slope)
# predict the output
y_pred2 = ((m*X) + b).reshape(4)


plt.scatter(x=X, y=y)
plt.plot(X, lr.predict(X=X), color="red", label="OLS")
plt.plot(X, y_pred, color="green", label="b=-10")
plt.plot(X, y_pred1, color="blue", label="b={}".format(round(b,4)))
plt.plot(X, y_pred2, color="pink", label="b={}".format(round(b,4)))
plt.legend()
plt.show()

# %% [markdown]
# ### iteration-3

# %%
# Lets take learning rate = 0.1
learning_rate = 0.1

# calculate the slope value
slope = -2 * np.mean(y - (m*X.ravel()) - b)
# updating the intercept value or b
b = b - (learning_rate * slope)
# predict the output
y_pred3 = ((m*X) + b).reshape(4)


plt.scatter(x=X, y=y)
plt.plot(X, lr.predict(X=X), color="red", label="OLS")
plt.plot(X, y_pred, color="green", label="b=-10")
plt.plot(X, y_pred1, color="blue", label="b={}".format(round(b,4)))
plt.plot(X, y_pred2, color="pink", label="b={}".format(round(b,4)))
plt.plot(X, y_pred3, color="yellow", label="b={}".format(round(b,4)))
plt.legend()
plt.show()

# %% [markdown]
# ### iteration-4

# %%
# Lets take learning rate = 0.1
learning_rate = 0.1

# calculate the slope value
slope = -2 * np.mean(y - (m*X.ravel()) - b)
# updating the intercept value or b
b = b - (learning_rate * slope)
# predict the output
y_pred4 = ((m*X) + b).reshape(4)


plt.scatter(x=X, y=y)
plt.plot(X, lr.predict(X=X), color="red", label="OLS")
plt.plot(X, y_pred, color="green", label="b=-10")
plt.plot(X, y_pred1, color="blue", label="b={}".format(round(b,4)))
plt.plot(X, y_pred2, color="pink", label="b={}".format(round(b,4)))
plt.plot(X, y_pred3, color="yellow", label="b={}".format(round(b,4)))
plt.plot(X, y_pred4, color="black", label="b={}".format(round(b,4)))
plt.legend()
plt.show()

# %% [markdown]
# ### iteration-5

# %%
# Lets take learning rate = 0.1
learning_rate = 0.1

# calculate the slope value
slope = -2 * np.mean(y - (m*X.ravel()) - b)
# updating the intercept value or b
b = b - (learning_rate * slope)
# predict the output
y_pred5 = ((m*X) + b).reshape(4)


plt.scatter(x=X, y=y)
plt.plot(X, lr.predict(X=X), color="red", label="OLS")
plt.plot(X, y_pred, color="green", label="b=-10")
plt.plot(X, y_pred1, color="blue", label="b={}".format(round(b,4)))
plt.plot(X, y_pred2, color="pink", label="b={}".format(round(b,4)))
plt.plot(X, y_pred3, color="yellow", label="b={}".format(round(b,4)))
plt.plot(X, y_pred4, color="black", label="b={}".format(round(b,4)))
plt.plot(X, y_pred5, color="orange", label="b={}".format(round(b,4)))
plt.legend()
plt.show()

# %%
# demo test
m * X.ravel()
# Out:
# array([-168.48251809,   14.10369451,    7.31154887,  -65.52777323])

# %%
# demo test
m*X
# Out:
# array([[-168.48251809],
#        [  14.10369451],
#        [   7.31154887],
#        [ -65.52777323]])

# %%
# let's create a function

def gradient_descent(b=0, learning_rate=0.01, epochs=100):
    
    b_value = []
    
    for i in range(epochs):
        # Find the slope
        slope = -2 * np.mean(y - (m*X.ravel()) - b)
        # update the b value
        b = b - (learning_rate * slope)
        b_value.append(b)
        # predict the y_pred
        y_pred = (m*X) + b

        plt.plot(X, y_pred)
    
    plt.scatter(x=X, y=y)
    plt.plot(X, lr.predict(X=X), color="red")
    
    print(b_value)

# %%
gradient_descent(learning_rate=0.1,epochs=50)
# Out:
# [8.677099056013075, 15.618778300823536, 21.172121696671905, 25.6147964133506, 29.168936186693557, 32.01224800536792, 34.286897460307415, 36.10661702425901, 37.562392675420284, 38.727013196349304, 39.65870961309252, 40.40406674648709, 41.000352453202744, 41.47738101857527, 41.859003870873295, 42.16430215271171, 42.40854077818245, 42.603931678559036, 42.7602443988603, 42.88529457510132, 42.98533471609413, 43.06536682888838, 43.129392519123776, 43.180613071312095, 43.22158951306275, 43.25437066646328, 43.2805955891837, 43.301575527360036, 43.318359477901105, 43.33178663833396, 43.34252836668024, 43.35112174935727, 43.35799645549889, 43.36349622041219, 43.36789603234283, 43.37141588188734, 43.37423176152294, 43.37648446523143, 43.37828662819822, 43.37972835857165, 43.38088174287039, 43.38180445030939, 43.38254261626059, 43.383133149021546, 43.38360557523031, 43.383983516197326, 43.384285868970935, 43.38452775118982, 43.38472125696493, 43.38487606158502]

# %% [markdown]
# ### Gradient Descent-animation for 'b'

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
# Let's plot it

plt.scatter(x=X, y=y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
reg = LinearRegression()
reg.fit(X=X, y=y)

print(reg.coef_)
print(reg.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
b = -150
m = 27.82809103
lr = 0.001
epochs = 30

all_b = []

all_cost = []



for i in range(epochs):
    slope = 0
    cost = 0
    for j in range(X.shape[0]):
        slope = slope - 2*(y[j] - (m * X[j]) -  b)
        cost = cost + (y[j] - m * X[j] - b) ** 2

    b = b - (lr * slope)
    all_b.append(b)
    all_cost.append(cost)
    y_pred = m * X + b
    
    plt.plot(X, y_pred)
    
plt.scatter(X,y)
plt.show()

# %%
all_b
# Out:
# [array([-120.45894891]),
#  array([-96.82610804]),
#  array([-77.91983534]),
#  array([-62.79481719]),
#  array([-50.69480266]),
#  array([-41.01479104]),
#  array([-33.27078174]),
#  array([-27.07557431]),
#  array([-22.11940836]),
#  array([-18.1544756]),
#  array([-14.98252939]),
#  array([-12.44497242]),
#  array([-10.41492685]),
#  array([-8.79089039]),
#  array([-7.49166123]),
#  array([-6.45227789]),
#  array([-5.62077123]),
#  array([-4.95556589]),
#  array([-4.42340163]),
#  array([-3.99767021]),
#  array([-3.65708508]),
#  array([-3.38461698]),
#  array([-3.16664249]),
#  array([-2.99226291]),
#  array([-2.85275924]),
#  array([-2.7411563]),
#  array([-2.65187395]),
#  array([-2.58044807]),
#  array([-2.52330737]),
#  array([-2.47759481])]

# %%
all_b = np.array(all_b).ravel()

all_b
# Out:
# array([-120.45894891,  -96.82610804,  -77.91983534,  -62.79481719,
#         -50.69480266,  -41.01479104,  -33.27078174,  -27.07557431,
#         -22.11940836,  -18.1544756 ,  -14.98252939,  -12.44497242,
#         -10.41492685,   -8.79089039,   -7.49166123,   -6.45227789,
#          -5.62077123,   -4.95556589,   -4.42340163,   -3.99767021,
#          -3.65708508,   -3.38461698,   -3.16664249,   -2.99226291,
#          -2.85275924,   -2.7411563 ,   -2.65187395,   -2.58044807,
#          -2.52330737,   -2.47759481])

# %%
all_cost = np.array(all_cost).ravel()
all_cost
# Out:
# array([2210026.52410458, 1424620.1946435 ,  921960.14378841,
#         600257.71124116,  394368.15441091,  262598.83803956,
#         178266.47556189,  124293.76357618,   89751.22790533,
#          67644.00507598,   53495.3824652 ,   44440.2639943 ,
#          38644.98817292,   34936.01164724,   32562.26667081,
#          31043.06988589,   30070.78394354,   29448.52094044,
#          29050.27261845,   28795.39369238,   28632.2711797 ,
#          28527.87277158,   28461.05779038,   28418.29620242,
#          28390.92878612,   28373.41363969,   28362.20394597,
#          28355.02974199,   28350.43825145,   28347.4996975 ])

# %%
fig, ax = plt.subplots(figsize=(9,5))

# fig.set_tight_layout(True)

x_i = np.arange(-3, 3, 0.1)

y_i = x_i*m -150

ax.scatter(X, y)

line, = ax.plot(x_i, x_i*50 - 4, 'r-', linewidth=2)

def update(i):
    label = 'epoch {0}'.format(i + 1)
    line.set_ydata(x_i*m + all_b[i])
    ax.set_xlabel(label)
    # return line, ax

anim = FuncAnimation(fig, update, repeat=True, frames=epochs, interval=500)

#f = r"animation.gif" 
#writergif = animation.PillowWriter(fps=2) 
#anim.save(f, writer=writergif)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
import matplotlib.pyplot as plt
import matplotlib.animation
import numpy as np

fig, ax = plt.subplots()
ax.plot(all_b, all_cost)
x, y = [],[]
sc = ax.scatter(x,y,color='red',marker='+')
plt.xlim(-150,50)
plt.ylim(0,2500000)

def animate(i):
    label = 'epoch {0}'.format(i + 1)
    x.append(all_b[i])
    y.append(all_cost[i])
    sc.set_offsets(np.c_[x,y])
    ax.set_xlabel(label)

ani = matplotlib.animation.FuncAnimation(fig, animate, 
                frames=30, interval=500, repeat=True) 
plt.show()

f = r"animation3.gif" 
writergif = animation.PillowWriter(fps=2) 
ani.save(f, writer=writergif)
# Out:
# <img src="data:image/png;base64,..." width="640">
